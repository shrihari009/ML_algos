# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("/content/diabetes.csv")

# %%
df.head(3)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1

# %%
df['Age'].std()
# Out:
# 11.760231540678685

# %%
features = df.drop(columns='Outcome', axis=1)
target = df['Outcome']

# %%
scaler = StandardScaler()

# %%
scaler.fit(features)
# Out:
# StandardScaler()

# %%
features = scaler.transform(features)

# %%
type(features)
# Out:
# numpy.ndarray

# %%
len(features)
# Out:
# 768

# %%
xtrain, xtest, ytrain, ytest = train_test_split(features, target, test_size = 0.19, random_state = 4)

# %%
xtrain.shape
# Out:
# (622, 8)

# %%
svm = SVC(a)

# %%
svm.fit(xtrain, ytrain)
# Out:
# SVC(kernel='linear')

# %%
xtrain_prediction = svm.predict(xtrain)

# %%
accuracy_score(ytrain, xtrain_prediction)
# Out:
# 0.7765273311897106

# %%
xtest_prediction = svm.predict(xtest)

# %%
accuracy_score(ytest, xtest_prediction)
# Out:
# 0.8013698630136986
