# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn import tree

# %%
df = pd.read_csv("/content/Decision_Tree_ Dataset.csv", sep=',', header=0)

# %%
df.head()
# Out:
#      1      2    3     4    sum Unnamed: 5
# 0  201  10018  250  3046  13515        yes
# 1  205  10016  395  3044  13660        yes
# 2  257  10129  109  3251  13746        yes
# 3  246  10064  324  3137  13771        yes
# 4  117  10115  496  3094  13822        yes

# %%
df.shape
# Out:
# (1000, 6)

# %%
df.columns = ["Initial Payment", "Last Payment", "Credit Score", "House Number", "Sum", "Result"]

# %%
df['Result'].value_counts()
# Out:
# No     521
# yes    479
# Name: Result, dtype: int64

# %%
x = df.drop(columns=["Result", "Sum"], axis=1)
y = df["Result"]

# %%
x.head()
# Out:
#    Initial Payment  Last Payment  Credit Score  House Number
# 0              201         10018           250          3046
# 1              205         10016           395          3044
# 2              257         10129           109          3251
# 3              246         10064           324          3137
# 4              117         10115           496          3094

# %%
y.head()
# Out:
# 0    yes
# 1    yes
# 2    yes
# 3    yes
# 4    yes
# Name: Result, dtype: object

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.31, random_state=77)

# %%
clf_entropy = DecisionTreeClassifier(criterion="entropy", random_state=100, max_depth=3, min_samples_leaf=5)

# %%
clf_entropy.fit(xtrain, ytrain)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, min_samples_leaf=5,
#                        random_state=100)

# %%
ypredict = clf_entropy.predict(xtest)

# %%
len(ypredict)
# Out:
# 310

# %%
accuracy_score(ytest, ypredict)
# Out:
# 0.9161290322580645
