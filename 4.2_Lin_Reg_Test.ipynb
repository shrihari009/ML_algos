# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/salary_data.csv")
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
model = LinearRegression()

# %%
x = df.drop(columns='Salary', axis=1)
y = df['Salary']

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.17, random_state=3)

# %%
model.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
xtest_prediction = model.predict(xtest)

# %%
xtest_prediction
# Out:
# array([ 72348.74519846,  53511.61125108, 100604.44611953, 115674.15327744,
#         81767.31217215,  68581.31840899])

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
mean_squared_error(ytest, xtest_prediction)**0.5
# Out:
# 3816.332048804824

# %%
r2_score(ytest, xtest_prediction)
# Out:
# 0.9695039421049821

# %%
numlist = [i/100 for i in range(10, 31)]
