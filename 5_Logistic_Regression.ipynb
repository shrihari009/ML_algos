# %%
import numpy as np

# %%
class logistic_regression():

  # declaring hyperparameters
  def __init__(self, learning_rate, no_of_iterations):

    self.learning_rate = learning_rate
    self.no_of_iterations = no_of_iterations

  # fit function to train the model with dataset
  def fit(self, X, Y):

    self.m, self.n = X.shape

    # initiating weights and bias vaalues

    self.w = np.zeros(self.n)
    self.b = 0

    self.X = X
    self.Y = Y

    # implemeting gradient descent

    for i in range(self.no_of_iterations):
      self.update_weights


  def update_weights(self):

    # Y cap formula in sigmoid function

    Y_cap = 1/(1 + np.exp(-(self.X.dot(self.w)+self.b))) # z = wX+b

    # derivatives

    dw = -(1/self.m)*np.dot(self.X.T, (Y_cap - self.Y))

    db = -(1/self.m)*np.sum(Y_cap - self.Y)

    # updating weights and bias using graident descent

    self.w = self.w - self.learning_rate * dw

    self.b = self.b - self.learning_rate * db

  # sigmoid function and decision boundry

  def predict(self, X):

    Y_predict = 1/(1 + np.exp(-(self.X.dot(self.w)+self.b)))

    Y_predict = np.where( Y_predict > 0.5, 1, 0)

    return Y_predict

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
diadf = pd.read_csv("/content/diabetes.csv")

# %%
diadf
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
X = diadf.drop(columns='Outcome', axis = 1) # dropping column: axis=1 and dropping row axis=0
Y = diadf['Outcome']

# %%
scaler = StandardScaler()

# %%
scaler.fit(X)
# Out:
# StandardScaler()

# %%
X = scaler.transform(X)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=2)

# %%
model = logistic_regression(0.01, 1000)

# %%
model.fit(X_train, Y_train)

# %%
X_train_prediction = model.predict(X_train)

# %%
model.b
# Out:
# 0

# %%
model.w
# Out:
# array([0., 0., 0., 0., 0., 0., 0., 0.])

# %% [markdown]
# Model Evaluation

# %%
train_data_accuracy = accuracy_score( Y_train, X_train_prediction)

# %%
train_data_accuracy
# Out:
# 0.6368078175895765
